# %% [markdown]
# ## Prueba del modelo
#
# En este notebook realizaremos la prueba con inferencias del modelo generado con el algoritmo RandomForest.

# %% [markdown]
# Cargamos las librerías a utilizar

# %%
import pickle
import cv2
from utils import get_face_landmarks

# %% [markdown]
# Definimo una lista con las clases

# %%
emotions = ['HAPPY', 'SAD', 'SURPRISED']

# %% [markdown]
# Cargamos el modelo generado en formato pickle

# %%
with open('./model', 'rb') as f:
    model = pickle.load(f)

# %% [markdown]
# Abrimos la camara del pc para realizar lectura

# %%
cap = cv2.VideoCapture(0)
ret, frame = cap.read()

# %% [markdown]
# Generamos las inferencias en linea

# %%
while ret:
    ret, frame = cap.read()

    face_landmarks = get_face_landmarks(frame, draw=True, static_image_mode=False)

    output = model.predict([face_landmarks])

    cv2.putText(frame,
                emotions[int(output[0])],
               (10, frame.shape[0] - 1),
               cv2.FONT_HERSHEY_SIMPLEX,
               3,
               (0, 255, 0),
               5)

    cv2.imshow('frame', frame)

    cv2.waitKey(25)


cap.release()
cv2.destroyAllWindows()
# Out:
# c:\Users\SSsarboleda\Desktop\Proyectos\Personal\Computer Vision\computer-vision-face-emotion-detection\.venv\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# c:\Users\SSsarboleda\Desktop\Proyectos\Personal\Computer Vision\computer-vision-face-emotion-detection\.venv\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# ...
